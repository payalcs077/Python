# %%
print("hello")
# Out:
# hello

# %%
a = [1,2,3]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
a = [1,2,3]
print(id(a))
a.append(5)
print(a)
print(id(a))
# Out:
# 4515055936
# [1, 2, 3, 5]
# 4515055936

# %%
a.clear()
print(a)
# Out:
# []

# %%
a = [1,2,3]
b = [4,5,6]
# a.extend(b)
# print(a)

i = 0
while a[i]<len(b):
    a.append(b[i])
    i = i+1
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=[1,2,3]
for i in dir(a):
    print(i)
# Out:
# __add__
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __delitem__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getstate__
# __gt__
# __hash__
# __iadd__
# __imul__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __reversed__
# __rmul__
# __setattr__
# __setitem__
# __sizeof__
# __str__
# __subclasshook__
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
a=[1,2,3]
for i in dir(a):
    if not (i.startswith('__') and i.endswith('__')):
        print(i)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
donation  = [1,2,3,1,1,1,4,5,6,7,8]
print(donation.count(6))
# Out:
# 1

# %%
a = [5,6,1,2,9,100]
a.sort()
print(a)
# Out:
# [1, 2, 5, 6, 9, 100]

# %%
a = [5,6,1,2,9,100]
a.sort(reverse=True)
print(a)
# Out:
# [100, 9, 6, 5, 2, 1]

# %%
a = [1,2,3]
b = a.copy()
b[0] = 1234
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1234, 2, 3]

# %%
a=[1,2,3]
x = dir(list)
x.reverse()
print(x)
# Out:
# ['sort', 'reverse', 'remove', 'pop', 'insert', 'index', 'extend', 'count', 'copy', 'clear', 'append', '__subclasshook__', '__str__', '__sizeof__', '__setitem__', '__setattr__', '__rmul__', '__reversed__', '__repr__', '__reduce_ex__', '__reduce__', '__new__', '__ne__', '__mul__', '__lt__', '__len__', '__le__', '__iter__', '__init_subclass__', '__init__', '__imul__', '__iadd__', '__hash__', '__gt__', '__getstate__', '__getitem__', '__getattribute__', '__ge__', '__format__', '__eq__', '__doc__', '__dir__', '__delitem__', '__delattr__', '__contains__', '__class_getitem__', '__class__', '__add__']

# %%
t = (10,)
print(type(t))
# Out:
# <class 'tuple'>

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t = (1,2,3,4)
len(t)
# Out:
# 4

# %%
t = (130,324,0,2,0,33)
print(min(t))
print(max(t))
print(sum(t))
print(t[0:5])
print(t[-1])
# Out:
# 0
# 324
# 489
# (130, 324, 0, 2, 0)
# 33

# %%
d1={
    1:"apple",
    2:"banana",
    3:"cherry"
}
l1=[]
l2=[]
for x,y in d1.items():
    l1.append(x)
    l2.append(y)
print(l1)
print(l2)
# Out:
# [1, 2, 3]
# ['apple', 'banana', 'cherry']

# %%
d1={
    1:{ 'a': 12,'b': 13},
    2: {'language':'Python','Skills':'Full Stack'}
}
d1
# Out:
# {1: {'a': 12, 'b': 13}, 2: {'language': 'Python', 'Skills': 'Full Stack'}}

# %%
#set
student = {"bob","tom","raju"}
print(student)
# Out:
# {'tom', 'raju', 'bob'}

# %%
dir(student)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
l1 = [1,2,3,4,5,5,1,2]
l2=set(l1)
x=list(l2)
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
s1={1,2,3}
s1.update({4,5,6})
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={1,2,3}
x = set(dir(a))
print(x)
# Out:
# {'discard', '__sub__', '__reduce_ex__', 'symmetric_difference', 'update', '__class_getitem__', '__len__', '__le__', 'copy', 'difference', '__getattribute__', 'add', '__getstate__', 'pop', '__or__', '__contains__', 'symmetric_difference_update', '__reduce__', 'issubset', 'union', '__doc__', '__sizeof__', '__setattr__', 'intersection_update', '__gt__', '__ne__', '__dir__', '__rsub__', '__repr__', '__rxor__', '__and__', '__isub__', '__ror__', '__class__', '__ior__', '__init_subclass__', '__iter__', '__ixor__', 'clear', '__format__', '__subclasshook__', '__ge__', '__xor__', '__rand__', '__eq__', 'difference_update', 'intersection', 'remove', '__delattr__', '__init__', '__str__', '__iand__', '__lt__', '__new__', '__hash__', 'isdisjoint', 'issuperset'}

# %%
import random

i = random.randint(1, 10)
print(i)

while True:
    n = int(input("Enter number between 1-10: "))

    if n == i:
        print("You have guessed the right number")
        break
    else:
        print("Wrong guess, try again!")
# Out:
# 9
# You have guessed the right number
