# %%
#Aggregation means one class holds another class using their objects

'''
class A
class B
obj1 = A()
obj2 = B('argument',obj1)
'''
# Out:
# "\nclass A\nclass B\nobj1 = A()\nobj2 = B('argument',obj1)\n"

# %%
class Student:
    def __init__(self, rollno, bank_details):
        self.rollno = rollno              # public
        self.__BankDetails = bank_details # private

    def show(self):
        print("Student Roll No:", self.rollno)
        print("Student Bank Details:", self.__BankDetails)


class Teacher:
    def __init__(self, student):
        self.__student = student  # private attribute (aggregation)

    def show_student(self):
        self.__student.show()

# %%
s1 = Student(101, "SBI - XXXX1234")
t1 = Teacher(s1)

t1.show_student()
# Out:
# Student Roll No: 101
# Student Bank Details: SBI - XXXX1234

# %%
'''x has a y => Aggregation
   x is a y => inheritance
'''
# Out:
# 'x has a y => Aggregation\n   x is a y => inheritance\n'

# %%
class User:
    def __init__(self):
        self.name = 'Tom'
        self.gender = 'male'

    def login(self):
        print('login')
class Student(User):
    def __init__(self):
        self.rollno = 100
    def enroll(self):
        print("Enroll student in the course")

# %%
s = Student()

# %%
class Parent:
    def __init__(self,num):
        self.__num = num
    def get_num(self):
        return self.__num
class Child(Parent):
    def __init__(self,val,num):
        super().__init__(num)
        self.__val = val
    def get_val(self):
        return self.__val
son = Child(100,10)
print("Parent: Num:",son.get_num())
print("child: Num:",son.get_val())
# Out:
# Parent: Num: 10
# child: Num: 100
