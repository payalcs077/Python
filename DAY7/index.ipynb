# %%
def add1(a,b):
    '''
Docstring for DAY7.index.ipynb
'''
    return a+b

# %%
help(add1)
# Out:
# Help on function add1 in module __main__:
#
# add1(a, b)
#     Docstring for DAY7.index.ipynb

# %%
a=2
b=2
print(id(a))
print(id(b))
print(a==b)
print(a is b)
# Out:
# 4384203576
# 4384203576
# True
# True

# %%
list1 = [1,2,3,4,5]
list2 = [1,2,3,4,5]
print(id(list1))
print(id(list2))
print(list1 == list2)
print(list1 is list2)
# Out:
# 4582294400
# 4582143488
# True
# False

# %%
set1 = {1,2,3}
set2 = {1,2,3}
print(id(set1))
print(id(set2))
print(set1 == set2)
print(set1 is set2)
# Out:
# 4508842272
# 4508841152
# True
# False

# %%
str1 = 'hello'
str2 = 'hello'
print(id(str1))
print(id(str2))
print(str1 == str2)
print(str1 is str2)
# Out:
# 4502976144
# 4502976144
# True
# True

# %%
list1 = [1,2,3,4]
list2 = lambda x : [i**2 for i in x]
print(list2(list1))
# Out:
# [1, 4, 9, 16]

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from sanitization_script import remove_html_chars
#       3 text = "<html>/Hello</html>"
#       4 cleaned = remove_html_chars(text)
#
# ImportError: cannot import name 'remove_html_chars' from 'sanitization_script' (/Users/payalmac/Python/venv/lib/python3.14/site-packages/sanitization_script/__init__.py)
